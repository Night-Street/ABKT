# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir("/content/drive/Othercomputers/陈成的thinkpad/ABKT")
# !python main.py
# Out:
# Checking the per-trained knowledge model...
# per-trained knowledge model is not existent...
# Training the knowledge model...
# Processed data is existent...
# Loading...
# Data is processed which has: 1080 students, 609 questions, 32 skills, 52301 records
# ******************** hyperparameters ********************
# k_hidden_num: 5
# guess: 0.25
# ******************** start training ********************
# ******************** Parameters: ********************
# user_initial_k: torch.Size([1080, 32])
# item_k: torch.Size([609, 32])
# user_improving_k: torch.Size([1080, 32, 5])
# item_improving_k: torch.Size([609, 32, 5])
# ******************** Parameters: ********************
# Epoch: 0 | BCEloss: 0.7895633 | ACC: 0.5346049471896293 | AUC: 0.6438873325083451
# Test ACC: 0.5268518518518519 | Test AUC: 0.7215683779349907
# Best ACC: 0.5268518518518519 | Best AUC: 0.7215683779349907
# Epoch: 1 | BCEloss: 0.75323236 | ACC: 0.5346049471896293 | AUC: 0.6824597964525039
# ...
